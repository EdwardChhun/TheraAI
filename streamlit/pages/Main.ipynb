# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(5,3),dpi=300)
plt.xlabel('Time (mins)')
plt.ylabel('Emotion intensity')
plt.show()

# %%
data = json.load(open('lang-reveal.json'))
scores = data['language']['predictions']
print(scores)

df = pd.DataFrame(columns=['Word', 'Score'])

joy_scores = []
sad_scores = []

print(scores[0]['emotions'][0]['name'])

for i in range(0, len(scores)):
    curr = scores[i]['emotions']
    for j in range(0, len(curr)):
        if curr[j]['name'] == 'Sadness':
            sad_scores.append(curr[j]['score'])
        elif curr[j]['name'] == 'Joy':
            joy_scores.append(curr[j]['score'])

x = np.arange(0, 60, 60/len(joy_scores))

plt.plot(x, joy_scores, marker='.', markersize=4)
plt.plot(x, sad_scores, marker='.', markersize=4)
plt.show()
# Out:
# [{'text': 'I', 'position': {'begin': 0, 'end': 1}, 'emotions': [{'name': 'Admiration', 'score': 0.0010817544534802437}, {'name': 'Adoration', 'score': 0.0012375462101772428}, {'name': 'Aesthetic Appreciation', 'score': 0.003842053934931755}, {'name': 'Amusement', 'score': 0.00805245153605938}, {'name': 'Anger', 'score': 0.00710755679756403}, {'name': 'Annoyance', 'score': 0.03341645002365112}, {'name': 'Anxiety', 'score': 0.08937067538499832}, {'name': 'Awe', 'score': 0.001771431532688439}, {'name': 'Awkwardness', 'score': 0.23132969439029694}, {'name': 'Boredom', 'score': 0.045530278235673904}, {'name': 'Calmness', 'score': 0.1610853672027588}, {'name': 'Concentration', 'score': 0.009868349879980087}, {'name': 'Confusion', 'score': 0.40328356623649597}, {'name': 'Contemplation', 'score': 0.09171298891305923}, {'name': 'Contempt', 'score': 0.02097262628376484}, {'name': 'Contentment', 'score': 0.0314454548060894}, {'name': 'Craving', 'score': 0.003434840589761734}, {'name': 'Determination', 'score': 0.004430962260812521}, {'name': 'Disappointment', 'score': 0.030400151386857033}, {'name': 'Disapproval', 'score': 0.018313435837626457}, {'name': 'Disgust', 'score': 0.005236069671809673}, {'name': 'Distress', 'score': 0.06459174305200577}, {'name': 'Doubt', 'score': 0.12673138082027435}, {'name': 'Ecstasy', 'score': 0.0022464466746896505}, {'name': 'Embarrassment', 'score': 0.022342253476381302}, {'name': 'Empathic Pain', 'score': 0.0065341186709702015}, {'name': 'Enthusiasm', 'score': 0.0026082699187099934}, {'name': 'Entrancement', 'score': 0.008643065579235554}, {'name': 'Envy', 'score': 0.0010232941713184118},